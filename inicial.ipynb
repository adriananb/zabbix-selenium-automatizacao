# %% [markdown]
# # Python Insights - Analisando Dados com Python
#
# ### Case - Cancelamento de Clientes
#
# Você foi contratado por uma empresa com mais de 800 mil clientes para um projeto de Dados. Recentemente a empresa percebeu que da sua base total de clientes, a maioria são clientes inativos, ou seja, que já cancelaram o serviço.
#
# Precisando melhorar seus resultados ela quer conseguir entender os principais motivos desses cancelamentos e quais as ações mais eficientes para reduzir esse número.
#
# Base de dados e arquivos: https://drive.google.com/drive/folders/1uDesZePdkhiraJmiyeZ-w5tfc8XsNYFZ?usp=drive_link

# %%
import pandas
tabela = pandas.read_csv("cancelamentos.csv")
tabela = tabela.drop(columns=[CustomerID])
display(tabela)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas
#       2 tabela = pandas.read_csv("cancelamentos.csv")
# ----> 3 tabela = tabela.drop(columns=[CustomerID])
#       4 display(tabela)
#       5
#
# NameError: name 'CustomerID' is not defined

# %%
display(tabela.info())
tabela = tabela.dropna()

# %%
# Passo 4: Analise Inicial (entender quantos clientes cancelaram)
# quantidade - contar quantos caras sao 0 e quantos sao 1 na coluna cancelou
display(tabela[cancelou].value_counts())

#porcentagem
display(tabela[cancelou].value_counts(normalize=True))

# %%
# Causa do cancelamento
import plotly.express as px
# cria o grafico 
grafico = px.histogram(tabela, x="cancelou" , color="causa_cancelamento", text_auto=True, title="Causa do cancelamento" ) 

# exibe o grafico
grafico.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 4
#       1 # Causa do cancelamento
#       2 import plotly.express as px
#       3 # cria o grafico
# ----> 4 grafico = px.histogram(tabela, x="cancelou" , color="causa_cancelamento", text_auto=True, title="Causa do cancelamento" )
#       5
#       6 # exibe o grafico
#       7 grafico.show()
#
# ...
